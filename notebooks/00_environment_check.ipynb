# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

print(sys.executable)
print(np.__version__)

x = np.linspace(-5, 5, 200)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Jupyter notebook test")
plt.show()
# Out:
# /Users/dileep.kalathil/Code/ml-crash-course/.venv/bin/python
# 2.4.6
